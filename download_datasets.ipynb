# %%
# !pip3 install datasets
# Out:
# Requirement already satisfied: datasets in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (2.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (1.21.5)
# Requirement already satisfied: tqdm>=4.62.1 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: packaging in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (23.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (2023.1.0)
# Requirement already satisfied: importlib-metadata in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (6.6.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (0.16.4)
# Requirement already satisfied: pandas in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (1.3.5)
# Requirement already satisfied: xxhash in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: aiohttp in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: requests>=2.19.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: multiprocess in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: asynctest==0.13.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (4.4.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: filelock in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: zipp>=0.5 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from importlib-metadata->datasets) (3.13.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/eliu/anaconda3/envs/urop_emi2/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)

# %%
# imports.
from datasets import load_dataset
import os

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ## Celeb-A Faces

# %%
dataset = load_dataset("nielsr/CelebA-faces")
# Out:
# Found cached dataset parquet (/home/eliu/.cache/huggingface/datasets/nielsr___parquet/nielsr--CelebA-faces-00908b91f44a46a2/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 202599
#     })
# })

# %%
dataset['train'][4]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218 at 0x7F178BC02410>

# %%
n_images = 100

for i in range(n_images):
    image = dataset['train'][i]['image']
    image.save(f"./celebA/ref/image_{i}.jpg")
